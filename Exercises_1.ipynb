# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import sys
# !{sys.executable} -m pip install --user numpy
# !{sys.executable} -m pip install --user pandas
# Out:
# Requirement already satisfied: numpy in c:\users\carlo\appdata\roaming\python\python310\site-packages (1.24.2)
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pandas
#   Downloading pandas-2.0.0-cp311-cp311-win_amd64.whl (11.2 MB)
#      ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.2 MB 186.2 kB/s eta 0:01:00
#      --------------------------------------- 0.1/11.2 MB 272.3 kB/s eta 0:00:41
#      --------------------------------------- 0.1/11.2 MB 301.2 kB/s eta 0:00:37
#      --------------------------------------- 0.1/11.2 MB 385.0 kB/s eta 0:00:29
#       -------------------------------------- 0.2/11.2 MB 523.5 kB/s eta 0:00:22
#       -------------------------------------- 0.2/11.2 MB 597.3 kB/s eta 0:00:19
#      - ------------------------------------- 0.3/11.2 MB 754.8 kB/s eta 0:00:15
#      - ------------------------------------- 0.5/11.2 MB 992.4 kB/s eta 0:00:11
#      -- ------------------------------------- 0.6/11.2 MB 1.3 MB/s eta 0:00:09
#      --- ------------------------------------ 0.9/11.2 MB 1.6 MB/s eta 0:00:07
#      ---- ----------------------------------- 1.2/11.2 MB 2.1 MB/s eta 0:00:05
#      ------ --------------------------------- 1.7/11.2 MB 2.6 MB/s eta 0:00:04
#      ------- -------------------------------- 2.2/11.2 MB 3.2 MB/s eta 0:00:03
#      --------- ------------------------------ 2.7/11.2 MB 3.7 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.2/11.2 MB 4.1 MB/s eta 0:00:02
#      ------------- -------------------------- 3.7/11.2 MB 4.4 MB/s eta 0:00:02
#      -------------- ------------------------- 4.2/11.2 MB 4.9 MB/s eta 0:00:02
#      ---------------- ----------------------- 4.6/11.2 MB 5.1 MB/s eta 0:00:02
#      ------------------ --------------------- 5.1/11.2 MB 5.4 MB/s eta 0:00:02
#      -------------------- ------------------- 5.7/11.2 MB 5.7 MB/s eta 0:00:01
#      ---------------------- ----------------- 6.2/11.2 MB 5.9 MB/s eta 0:00:01
#      ----------------------- ---------------- 6.7/11.2 MB 6.1 MB/s eta 0:00:01
#      ------------------------- -------------- 7.2/11.2 MB 6.3 MB/s eta 0:00:01
#      --------------------------- ------------ 7.7/11.2 MB 6.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 8.2/11.2 MB 6.6 MB/s eta 0:00:01
#      ------------------------------- -------- 8.7/11.2 MB 6.8 MB/s eta 0:00:01
#      -------------------------------- ------- 9.2/11.2 MB 6.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 9.7/11.2 MB 7.0 MB/s eta 0:00:01
#      ------------------------------------ --- 10.2/11.2 MB 7.2 MB/s eta 0:00:01
#      ------------------------------------- - 10.7/11.2 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  11.2/11.2 MB 10.7 MB/s eta 0:00:01
#      --------------------------------------  11.2/11.2 MB 10.7 MB/s eta 0:00:01
#      --------------------------------------  11.2/11.2 MB 10.7 MB/s eta 0:00:01
#      --------------------------------------  11.2/11.2 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------------- 11.2/11.2 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python311\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ---------------------------------------- 0.0/502.3 kB ? eta -:--:--
#      ------------------------------------- 502.3/502.3 kB 10.5 MB/s eta 0:00:00
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in c:\python311\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.0.0 pytz-2023.3 tzdata-2023.3
# ^C

# %%
# !{sys.executable} -m pip install --user matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp310-cp310-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\carlo\appdata\roaming\python\python310\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\carlo\appdata\roaming\python\python310\site-packages (from matplotlib) (1.24.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\carlo\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB 2.8 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 9.1 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.3/98.3 kB 5.5 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp310-cp310-win_amd64.whl (162 kB)
#      -------------------------------------- 163.0/163.0 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\carlo\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.3 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 pyparsing-3.0.9
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !{sys.executable} -m pip install --user scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
#      ---------------------------------------- 42.5/42.5 MB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\carlo\appdata\roaming\python\python310\site-packages (from scipy) (1.24.2)
# Installing collected packages: scipy
# Successfully installed scipy-1.10.1
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv(
    'data/sales_data.csv',
    parse_dates=['Date'])

# %%
sales.head(5)
# Out:
#          Date   Day     Month    Year  Customer_Age       Age_Group
# 0  2013-11-26  26.0  November  2013.0          19.0     Youth (<25)  \
# 1  2015-11-26  26.0  November  2015.0          19.0     Youth (<25)
# 2  2014-03-23  23.0     March  2014.0          49.0  Adults (35-64)
# 3  2016-03-23  23.0     March  2016.0          49.0  Adults (35-64)
# 4  2014-05-15  15.0       May  2014.0          47.0  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category
# 0               M     Canada  British Columbia      Accessories   Bike Racks  \
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit    Cost
# 0  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0  \
# 1  Hitch Rack - 4-Bike             8.0       45.0       120.0   590.0   360.0
# 2  Hitch Rack - 4-Bike            23.0       45.0       120.0  1366.0  1035.0
# 3  Hitch Rack - 4-Bike            20.0       45.0       120.0  1188.0   900.0
# 4  Hitch Rack - 4-Bike             4.0       45.0       120.0   238.0   180.0
#
#    Revenue
# 0    950.0
# 1    950.0
# 2   2401.0
# 3   2088.0
# 4    418.0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
sales['Customer_Age'].mean()
# Out:
# 35.98908892525914

# %% [markdown]
# Why don't you try with `.mean()`

# %%
sales['Customer_Age'].mean()
# Out:
# 35.98908892525914

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales['Order_Quantity'].mean()
# Out:
# 15.079811302589775

# %%
sales['Order_Quantity'].median()
# Out:
# 15.0

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, medianprops={"color": "green", "linewidth": 0.5}, showmeans=True, meanline=True, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales['Year'].value_counts()
# Out:
# Year
# 2014.0    17897
# 2016.0    17897
# 2013.0    13264
# 2015.0    13264
# Name: count, dtype: int64

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2014.0    17897
# 2016.0    17897
# 2013.0    13264
# 2015.0    13264
# Name: count, dtype: int64

# %%
sales['Year']
# Out:
# 0         2013.0
# 1         2015.0
# 2         2014.0
# 3         2016.0
# 4         2014.0
#            ...
# 113031       NaN
# 113032       NaN
# 113033       NaN
# 113034       NaN
# 113035       NaN
# Name: Year, Length: 113036, dtype: float64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here
fig, ax = plt.subplots()
ax.pie(sales['Year'].value_counts(), labels = sales['Year'].unique())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 3
#       1 # your code goes here
#       2 fig, ax = plt.subplots()
# ----> 3 ax.pie(sales['Year'].value_counts(), labels = sales['Year'].unique())
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
#    1463                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axes\_axes.py:3209, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3207     explode = [0] * len(x)
#    3208 if len(x) != len(labels):
# -> 3209     raise ValueError("'label' must be of length 'x'")
#    3210 if len(x) != len(explode):
#    3211     raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'

# %%
sales['Year'].unique()
# Out:
# array([2013., 2015., 2014., 2016.,   nan])

# %%
sales['Year'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
sales['Month'].value_counts()
# Out:
# Month
# December     5908
# May          5878
# June         5790
# April        5524
# March        5330
# January      5212
# October      5044
# February     4994
# November     4914
# August       4786
# September    4622
# July         4320
# Name: count, dtype: int64

# %%
sales['Month'].value_counts()
# Out:
# Month
# December     5908
# May          5878
# June         5790
# April        5524
# March        5330
# January      5212
# October      5044
# February     4994
# November     4914
# August       4786
# September    4622
# July         4320
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales['Month'].value_counts().plot(kind='bar', color='red', figsize=(14,6))
# Out:
# <Axes: xlabel='Month'>

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
sales['Country'].value_counts()
# Out:
# Country
# United States     22354
# Australia         11996
# Canada             9252
# United Kingdom     7146
# France             5832
# Germany            5742
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().head(1)
# Out:
# Country
# United States    22354
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     22354
# Australia         11996
# Canada             9252
# United Kingdom     7146
# France             5832
# Germany            5742
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales['Country'].value_counts().plot(kind='bar',  figsize=(14,6))
# Out:
# <Axes: xlabel='Country'>

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', nan, 'Hydration Pack - 70 oz.',
#        'Mountain Tire Tube', 'Touring Tire Tube', 'Patch Kit/8 Patches',
#        'HL Mountain Tire', 'LL Mountain Tire', 'Road Tire Tube',
#        'LL Road Tire', 'Touring Tire', 'ML Mountain Tire', 'HL Road Tire',
#        'ML Road Tire'], dtype=object)

# %%
#sales.loc[:, 'Product'].unique()

sales['Product'].unique()
np.size(sales['Product'].unique())
# Out:
# 21

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here
sales['Product'].value_counts().tail(12).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %%
sales['Product'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
#pd.to_numeric(sales, errors='ignore')
#sales['Date'] = sales['Date'].astype('datetime64').astype(int)
corr = sales.corr()
corr
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[136], line 3
#       1 #pd.to_numeric(sales, errors='ignore')
#       2 #sales['Date'] = sales['Date'].astype('datetime64').astype(int)
# ----> 3 corr = sales.corr()
#       4 corr
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:1837, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1835 if dtype is not None:
#    1836     dtype = np.dtype(dtype)
# -> 1837 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1838 if result.dtype is not dtype:
#    1839     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: '2013-11-26'

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Calculated_Date'].head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here

# %%
france_states.plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here

# %%
sales['Product_Category'].value_counts()

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()

accessories

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here

# %%
accessories.plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

bikes

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here

# %%
bikes.plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here

# %%
sales['Customer_Gender'].value_counts()

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
